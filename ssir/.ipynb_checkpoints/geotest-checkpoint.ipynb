# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

from shapely.geometry import box, Point
import random
import basestations as bs

def generate_random_points_within_gdf(maritime_gdf, num_points):
    """
    maritime GeoDataFrame 내에 랜덤 포인트를 생성합니다.
    
    Parameters:
        maritime_gdf (GeoDataFrame): maritime 영역의 GeoDataFrame
        num_points (int): 생성할 랜덤 포인트의 개수
    
    Returns:
        List[Point]: 생성된 랜덤 포인트 리스트
    """
    # maritime 영역의 전체 경계 가져오기
    minx, miny, maxx, maxy = maritime_gdf.total_bounds
    
    points = []
    attempts = 0
    max_attempts = num_points * 10  # 무한 루프 방지를 위한 최대 시도 횟수

    while len(points) < num_points and attempts < max_attempts:
        # 경계 박스 내에서 랜덤 좌표 생성
        random_lon = random.uniform(minx, maxx)
        random_lat = random.uniform(miny, maxy)
        point = Point(random_lon, random_lat)
        # 생성된 포인트가 maritime 영역 내에 있는지 확인
        if maritime_gdf.contains(point).any():
            points.append(point)
        attempts += 1

    if len(points) < num_points:
        print(f"Warning: Only {len(points)} points were generated after {attempts} attempts.")
    
    return points

def generate_random_points_within_bbox(bbox: box, num_points):
    """
    Generate random points within a given bounding box.

    Parameters:
        bbox (box): Bounding box within which to generate points.
        num_points (int): Number of random points to generate.

    Returns:
        List[Point]: List of generated random points.
    """
    minx, miny, maxx, maxy = bbox.bounds
    
    points = []
    for _ in range(num_points):
        random_lon = random.uniform(minx, maxx)
        random_lat = random.uniform(miny, maxy)
        points.append(Point(random_lon, random_lat))
    
    return points

# %%
# Set configurations
fontsize=16
markersize=15
target_crs = "EPSG:4326"
langitude_range = [116, 135]
longitude_range = [30, 37.5]

land_color = np.array([240, 255, 240]) / 255.0
water_color = np.array([212, 238, 255]) / 255.0
edge_color = np.array([0, 0, 0]) / 255.0

num_maritime_basestations = 8
num_ground_basestations = 15
num_haps_basestations = 7
num_leo_basestations = 4
num_users = 15

maritime_basestations_color = np.array([9, 72, 233]) / 255.0
ground_basestations_color = np.array([255, 0, 25]) / 255.0
haps_basestations_color = np.array([205, 0, 255]) / 255.0
leo_basestations_color = np.array([0, 0, 0]) / 255.0
maritime_basestations_color = "blue"
ground_basestations_color = "teal"
haps_basestations_color = "dodgerblue"
leo_basestations_color = "navy"

# 관심 영역의 경계 박스 생성 (경도: 120~150, 위도: 30~45)
bbox = box(minx=langitude_range[0], miny=longitude_range[0], maxx=langitude_range[1], maxy=longitude_range[1])
bbox_gdf = gpd.GeoDataFrame({'geometry': [bbox]}, crs=target_crs)

# 데이터 경로 설정
land_shp = "map/ne_10m_land/ne_10m_land.shp"
lakes_shp = "map/ne_10m_lakes/ne_10m_lakes.shp"
rivers_shp = "map/ne_10m_rivers_lake_centerlines/ne_10m_rivers_lake_centerlines.shp"
maritime_shp = "map/ne_10m_ocean/ne_10m_ocean.shp"

# GeoDataFrame으로 읽기
land = gpd.read_file(land_shp)
lakes = gpd.read_file(lakes_shp)
rivers = gpd.read_file(rivers_shp)
maritime = gpd.read_file(maritime_shp)  # maritime 데이터 불러오기

# 모든 GeoDataFrame이 동일한 CRS를 사용하는지 확인하고, 필요 시 변환
for df in [land, lakes, rivers, maritime]:
    if df.crs != target_crs:
        df.to_crs(target_crs, inplace=True)

# GeoPandas의 clip 함수를 사용하여 데이터를 경계 박스 내로 자르기
def clip_to_bbox(gdf, bbox):
    return gpd.clip(gdf, bbox)

maritime_filtered = clip_to_bbox(maritime, bbox_gdf)
land_filtered = clip_to_bbox(land, bbox_gdf)
lakes_filtered = clip_to_bbox(lakes, bbox_gdf)
rivers_filtered = clip_to_bbox(rivers, bbox_gdf)

source_basestation_point = generate_random_points_within_gdf(land_filtered, 1)
maritime_basestations_points = generate_random_points_within_gdf(maritime_filtered, num_maritime_basestations)
ground_basestations_points = generate_random_points_within_gdf(land_filtered, num_ground_basestations)
haps_basestations_points = generate_random_points_within_bbox(bbox, num_haps_basestations)
leo_basestations_points = generate_random_points_within_bbox(bbox, num_leo_basestations)
users_points = generate_random_points_within_bbox(bbox, num_users)

# 9. GeoDataFrame으로 변환
source_basestation_gdf = gpd.GeoDataFrame({'geometry': source_basestation_point}, crs=target_crs)
maritime_basestations_gdf = gpd.GeoDataFrame({'geometry': maritime_basestations_points}, crs=target_crs)
ground_basestations_gdf = gpd.GeoDataFrame({'geometry': ground_basestations_points}, crs=target_crs)
haps_basestations_gdf = gpd.GeoDataFrame({'geometry': haps_basestations_points}, crs=target_crs)
leo_basestations_gdf = gpd.GeoDataFrame({'geometry': leo_basestations_points}, crs=target_crs)
users_gdf = gpd.GeoDataFrame({'geometry': users_points}, crs=target_crs)

# 시각화
fig, ax = plt.subplots(figsize=(12, 8))

# 그리는 순서: maritime -> Land -> Lakes -> Rivers
if not maritime_filtered.empty:
    maritime_filtered.plot(ax=ax, color=water_color, zorder=1)
if not land_filtered.empty:
    land_filtered.plot(ax=ax, color=land_color, edgecolor=edge_color, linewidth=.5, zorder=1)
if not lakes_filtered.empty:
    lakes_filtered.plot(ax=ax, color=water_color, zorder=1)
if not rivers_filtered.empty:
    rivers_filtered.plot(ax=ax, color=water_color, zorder=1)

source_basestation_gdf.plot(ax=ax,
                            color='deeppink',
                            marker="*",
                            markersize=markersize*10,
                            label='Source Basestation',
                            zorder=2)
maritime_basestations_gdf.plot(ax=ax, 
                            color=maritime_basestations_color,
                            marker="o",
                            markersize=markersize,
                            label='Maritime Basestations',
                            zorder=2)
ground_basestations_gdf.plot(ax=ax,
                            color=ground_basestations_color,
                            marker="^",
                            markersize=markersize,
                            label='Ground Basestations',
                            zorder=2)
haps_basestations_gdf.plot(ax=ax,
                           color=haps_basestations_color,
                           marker="x",
                           markersize=markersize,
                           label='HAPS Basestations',
                           zorder=2)
leo_basestations_gdf.plot(ax=ax,
                          color=leo_basestations_color,
                          marker="s",
                          markersize=markersize,
                          label='LEO Basestations',
                          zorder=2)
users_gdf.plot(ax=ax,
               color='red',
               marker="d",
               markersize=markersize,
               label='Users',
               zorder=2)

# 플롯의 축 범위를 경계 박스로 설정
plt.xlim(*langitude_range)
plt.ylim(*longitude_range)

# 제목 및 범례 추가
plt.xlabel('Longitude', fontsize=fontsize)
plt.ylabel('Latitude', fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.legend(loc='lower left')

# %%
for node in graph.nodes:
    # get
    print()
# Out:
# 125.45848938413727

# %%
# 1. 기지국 및 유저 포인트를 경도, 위도 축에서 km 축으로 변환
# A) 내장 함수로 get_distance를 구현하여 local map인 경우, global map인 경우 모두 해결함.

############################################
# 2. 기지국 및 유저 위치를 기반으로 basestation 모듈 타입 생성후 그래프 노드로 추가.
############################################
import basestations as bs

# WARNING: BASESTATION order should be the same as the order of BaseStationType
basestations_points_list = [
    maritime_basestations_points,
    ground_basestations_points,
    haps_basestations_points,
    leo_basestations_points
]
basestations_altitude_list = [
    bs.environmental_variables.maritime_basestations_altitude,
    bs.environmental_variables.ground_basestations_altitude,
    bs.environmental_variables.haps_basestations_altitude,
    bs.environmental_variables.leo_basestations_altitude
]
basestations_nodes_list = []
users_node_list = []
# Add source node
node_id = 0
basestations_nodes_list.append(
    bs.BaseStation(node_id, 
                   np.array([source_basestation_point[0].x, source_basestation_point[0].y, 0]), 
                   bs.BaseStationType.GROUND)
)
node_id += 1

# Add basestations nodes
for i, points in enumerate(basestations_points_list):
    for point in points:
        node = bs.BaseStation(node_id, 
                              np.array([point.x, point.y, basestations_altitude_list[i]]), 
                              list(bs.BaseStationType)[i],
                              isGeographic=True,)
        basestations_nodes_list.append(node)
        node_id += 1

# Add users nodes
# TODO(?): distinguish ground user, maritime user, and aeiral users
for i, point in enumerate(users_points):
    node = bs.User(node_id, 
                   np.array([point.x, point.y, 0]), 
                   isGeographic=True
                   )
    users_node_list.append(node)
    node_id += 1

graph = bs.IABRelayGraph(bs.environmental_variables)
for node in basestations_nodes_list:
    graph.add_node(node)

for node in users_node_list:
    graph.add_node(node)

graph.connect_rechable_nodes()

############################################
# 3. 다익스트라 알고리즘 구현 (완료)
# 3-1. 도달 가능한 노드 계산 함수 구현 (완료)
# 3-2. 2가지 표준 IAB 릴레이 토폴로지(ST, DAG) 경로 구현 완료
#      최단 경로, 최소 홉, 최대 rate 경로 탐색 알고리즘 구현 완료
# ############################################
import pathfinder as pf
costs, predecessors = pf.a_star(graph)

# path를 plot에 추가
# TODO: 중복 plot 방지코드 작성
# connected_path = []
for user in graph.users:
    path = pf.get_shortest_path(predecessors, user._node_id)
    if path[0] != -1:
        path_x = [graph.nodes[node_id]._position[0] for node_id in path]
        path_y = [graph.nodes[node_id]._position[1] for node_id in path]
        ax.plot(path_x, path_y, color='black', linestyle='dashed', linewidth=1, zorder=3)

fig
############################################
# 4. Graph attention network 또는 AI기반 그래프 최적화 알고리즘 구현
############################################

############################################
# 5-1. 시뮬레이션 데이터에 대한 성능 평가
# 5-2. 실제 데이터에 대한 성능 평가
############################################

############################################
# 6. 결과 시각화
############################################
# Out:
# 0 443.59668923760205
# Node 0: 2.24, 0.62, 0.00, node 1: 2.22, 0.55, 0.00, distance: 290.51
# Node 0: 2.24, 0.62, 0.00, node 2: 2.19, 0.53, 0.00, distance: 463.01
# Node 0: 2.24, 0.62, 0.00, node 3: 2.33, 0.56, 0.00, distance: 606.79
# Node 0: 2.24, 0.62, 0.00, node 4: 2.18, 0.64, 0.00, distance: 389.18
# Node 0: 2.24, 0.62, 0.00, node 5: 2.29, 0.63, 0.00, distance: 329.80
# Node 0: 2.24, 0.62, 0.00, node 6: 2.16, 0.63, 0.00, distance: 537.23
# Node 0: 2.24, 0.62, 0.00, node 7: 2.15, 0.63, 0.00, distance: 583.91
# Node 0: 2.24, 0.62, 0.00, node 8: 2.28, 0.53, 0.00, distance: 458.07
# Node 0: 2.24, 0.62, 0.00, node 9: 2.12, 0.54, 0.25, distance: 828.68
# Node 0: 2.24, 0.62, 0.00, node 10: 2.12, 0.55, 0.25, distance: 806.95
# Node 0: 2.24, 0.62, 0.00, node 11: 2.04, 0.57, 0.25, distance: 1254.56
# Node 0: 2.24, 0.62, 0.00, node 12: 2.23, 0.61, 0.25, distance: 79.17
# Node 0: 2.24, 0.62, 0.00, node 13: 2.03, 0.63, 0.25, distance: 1332.66
# Node 0: 2.24, 0.62, 0.00, node 14: 2.09, 0.56, 0.25, distance: 979.61
# Node 0: 2.24, 0.62, 0.00, node 15: 2.06, 0.65, 0.25, distance: 1115.59
# Node 0: 2.24, 0.62, 0.00, node 16: 2.11, 0.64, 0.25, distance: 812.59
# Node 0: 2.24, 0.62, 0.00, node 17: 2.07, 0.64, 0.25, distance: 1074.51
# Node 0: 2.24, 0.62, 0.00, node 18: 2.28, 0.54, 0.25, distance: 428.82
# Node 0: 2.24, 0.62, 0.00, node 19: 2.08, 0.65, 0.25, distance: 994.53
# Node 0: 2.24, 0.62, 0.00, node 20: 2.33, 0.61, 0.25, distance: 610.99
# Node 0: 2.24, 0.62, 0.00, node 21: 2.34, 0.59, 0.25, distance: 636.62
# Node 0: 2.24, 0.62, 0.00, node 22: 2.05, 0.56, 0.25, distance: 1227.30
# Node 0: 2.24, 0.62, 0.00, node 23: 2.23, 0.62, 0.25, distance: 45.85
# Node 0: 2.24, 0.62, 0.00, node 24: 2.33, 0.62, 22.00, distance: 584.46
# Node 0: 2.24, 0.62, 0.00, node 25: 2.06, 0.53, 22.00, distance: 1208.08
# Node 0: 2.24, 0.62, 0.00, node 26: 2.25, 0.61, 22.00, distance: 93.68
# Node 0: 2.24, 0.62, 0.00, node 27: 2.10, 0.64, 22.00, distance: 913.21
# Node 0: 2.24, 0.62, 0.00, node 28: 2.12, 0.56, 22.00, distance: 788.30
# Node 0: 2.24, 0.62, 0.00, node 29: 2.08, 0.58, 22.00, distance: 991.98
# Node 0: 2.24, 0.62, 0.00, node 30: 2.35, 0.58, 22.00, distance: 695.07
# Node 0: 2.24, 0.62, 0.00, node 31: 2.35, 0.63, 500.00, distance: 848.69
# Node 0: 2.24, 0.62, 0.00, node 32: 2.20, 0.60, 500.00, distance: 561.58
# Node 0: 2.24, 0.62, 0.00, node 33: 2.15, 0.63, 500.00, distance: 737.56
# Node 0: 2.24, 0.62, 0.00, node 34: 2.16, 0.56, 500.00, distance: 738.78
# Node 0: 2.24, 0.62, 0.00, node 35: 2.12, 0.60, 0.00, distance: 774.73
# Node 0: 2.24, 0.62, 0.00, node 36: 2.35, 0.52, 0.00, distance: 817.27
# Node 0: 2.24, 0.62, 0.00, node 37: 2.34, 0.54, 0.00, distance: 736.45
# Node 0: 2.24, 0.62, 0.00, node 38: 2.26, 0.54, 0.00, distance: 348.31
# Node 0: 2.24, 0.62, 0.00, node 39: 2.08, 0.59, 0.00, distance: 1026.87
# Node 0: 2.24, 0.62, 0.00, node 40: 2.34, 0.59, 0.00, distance: 687.17
# Node 0: 2.24, 0.62, 0.00, node 41: 2.32, 0.54, 0.00, distance: 609.12
# Node 0: 2.24, 0.62, 0.00, node 42: 2.34, 0.59, 0.00, distance: 635.08
# Node 0: 2.24, 0.62, 0.00, node 43: 2.20, 0.53, 0.00, distance: 426.45
# Node 0: 2.24, 0.62, 0.00, node 44: 2.26, 0.59, 0.00, distance: 179.74
# Node 0: 2.24, 0.62, 0.00, node 45: 2.21, 0.60, 0.00, distance: 208.41
# Node 0: 2.24, 0.62, 0.00, node 46: 2.21, 0.59, 0.00, distance: 193.99
# Node 0: 2.24, 0.62, 0.00, node 47: 2.22, 0.57, 0.00, distance: 187.02
# Node 0: 2.24, 0.62, 0.00, node 48: 2.03, 0.59, 0.00, distance: 1331.27
# Node 0: 2.24, 0.62, 0.00, node 49: 2.03, 0.54, 0.00, distance: 1341.07
# Node 0: 2.24, 0.62, 0.00, node 1: 2.22, 0.55, 0.00, distance: 290.51
# Node 0: 2.24, 0.62, 0.00, node 4: 2.18, 0.64, 0.00, distance: 389.18
# Node 0: 2.24, 0.62, 0.00, node 5: 2.29, 0.63, 0.00, distance: 329.80
# Node 0: 2.24, 0.62, 0.00, node 12: 2.23, 0.61, 0.25, distance: 79.17
# Node 0: 2.24, 0.62, 0.00, node 18: 2.28, 0.54, 0.25, distance: 428.82
# Node 0: 2.24, 0.62, 0.00, node 23: 2.23, 0.62, 0.25, distance: 45.85
# Node 0: 2.24, 0.62, 0.00, node 26: 2.25, 0.61, 22.00, distance: 93.68
# Node 0: 2.24, 0.62, 0.00, node 38: 2.26, 0.54, 0.00, distance: 348.31
# Node 0: 2.24, 0.62, 0.00, node 43: 2.20, 0.53, 0.00, distance: 426.45
# Node 0: 2.24, 0.62, 0.00, node 44: 2.26, 0.59, 0.00, distance: 179.74
# Node 0: 2.24, 0.62, 0.00, node 45: 2.21, 0.60, 0.00, distance: 208.41
# Node 0: 2.24, 0.62, 0.00, node 46: 2.21, 0.59, 0.00, distance: 193.99
# Node 0: 2.24, 0.62, 0.00, node 47: 2.22, 0.57, 0.00, distance: 187.02

# %%
# 어떤 실험을 할 것인가?
